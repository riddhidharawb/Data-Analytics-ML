# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler


data = pd.read_csv('/content/drive/MyDrive/Mall_Customers.csv')

columns = ['Spending Score (1-100)']
data_selected = data[columns]

scaler = StandardScaler()
data_scaled = scaler.fit_transform(data_selected)

K = 5
kmeans = KMeans(n_clusters=K)
kmeans.fit(data_scaled)
labels = kmeans.predict(data_scaled)

data['Cluster'] = labels

print(data[['CustomerID', 'Spending Score (1-100)', 'Cluster']])

cluster_stats = data.groupby('Cluster')[['Spending Score (1-100)']].agg(['mean', 'std', 'count'])
print("Cluster Statistics:")
print(cluster_stats)
# Out:
#      CustomerID  Spending Score (1-100)  Cluster
# 0             1                      39        3
# 1             2                      81        4
# 2             3                       6        2
# 3             4                      77        4
# 4             5                      40        3
# ..          ...                     ...      ...
# 195         196                      79        4
# 196         197                      28        3
# 197         198                      74        4
# 198         199                      18        2
# 199         200                      83        0
#
# [200 rows x 3 columns]
# Cluster Statistics:
#         Spending Score (1-100)
#                           mean       std count
# Cluster
# 0                    90.703704  4.444658    27
# 1                    52.790323  4.855746    62
# 2                    11.846154  6.196512    39
# 3                    37.000000  5.579266    40
# 4                    74.250000  4.095631    32
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
